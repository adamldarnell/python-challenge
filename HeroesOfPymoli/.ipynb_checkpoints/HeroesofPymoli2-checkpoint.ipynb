# %%
import pandas as pd

# %%
pymoli1 = "purchase_data.json"
pymoli2 = "purchase_data2.json"

# %%
pymoli1_pd = pd.read_json(pymoli1)
pymoli2_pd = pd.read_json(pymoli2)

# %%
pymoli1_pd.head()
# Out:
#    Age Gender  Item ID                                  Item Name  Price  \
# 0   38   Male      165                Bone Crushing Silver Skewer   3.37
# 1   21   Male      119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2   34   Male      174                            Primitive Blade   2.46
# 3   21   Male       92                               Final Critic   1.36
# 4   23   Male       63                             Stormfury Mace   1.27
#
#              SN
# 0     Aelalis34
# 1        Eolo46
# 2   Assastnya25
# 3  Pheusrical25
# 4        Aela59

# %%
pymoli2_pd.head()
# Out:
#    Age Gender  Item ID                 Item Name  Price          SN
# 0   20   Male       93  Apocalyptic Battlescythe   4.49     Iloni35
# 1   21   Male       12                     Dawne   3.36   Aidaira26
# 2   17   Male        5                Putrid Fan   2.63      Irim47
# 3   17   Male      123         Twilight's Carver   2.55     Irith83
# 4   22   Male      154              Feral Katana   4.11  Philodil43

# %%
player_count = len(pymoli1_pd) + len(pymoli2_pd)
player_countP = pd.DataFrame({"Total Player Count": [player_count]})
player_countP
# Out:
#    Total Player Count
# 0                 858

# %%
pymoli1_rename = pymoli1_pd.rename(columns={'Item ID': 'ItemID', 'Item Name': 'ItemName'})
pymoli2_rename = pymoli1_pd.rename(columns={'Item ID': 'ItemID', 'Item Name': 'ItemName'})

# %%
list(set(pymoli1_rename.ItemName))
# Out:
# ['Mourning Blade',
#  'Vindictive Glass Edge',
#  'Heartseeker, Reaver of Souls',
#  'Aetherius, Boon of the Blessed',
#  'Curved Axe',
#  'Conqueror Adamantite Mace',
#  'Mercenary Sabre',
#  'Thunderfury Scimitar',
#  'Glimmer, Ender of the Moon',
#  'Dreamkiss',
#  'Warped Diamond Crusader',
#  'Fury',
#  'Alpha',
#  'Righteous Might',
#  'Yearning Crusher',
#  'Soul Infused Crystal',
#  'Lifebender',
#  'Expiration, Warscythe Of Lost Worlds',
#  'Retribution Axe',
#  "Bloodlord's Fetish",
#  'Heartstriker, Legacy of the Light',
#  'Shadow Strike, Glory of Ending Hope',
#  'Brimstone',
#  "Dragon's Greatsword",
#  'Brutality Ivory Warmace',
#  'Lightning, Etcher of the King',
#  'Glinting Glass Edge',
#  'Serenity',
#  'Interrogator, Blood Blade of the Queen',
#  'Downfall, Scalpel Of The Emperor',
#  'Hailstorm Shadowsteel Scythe',
#  'Frenzied Scimitar',
#  'Celeste, Incarnation of the Corrupted',
#  'Piece Maker',
#  'Soul-Forged Steel Shortsword',
#  'Severance',
# ...

# %%
list(set(pymoli2_rename.ItemName))
# Out:
# ['Mourning Blade',
#  'Vindictive Glass Edge',
#  'Heartseeker, Reaver of Souls',
#  'Aetherius, Boon of the Blessed',
#  'Curved Axe',
#  'Conqueror Adamantite Mace',
#  'Mercenary Sabre',
#  'Thunderfury Scimitar',
#  'Glimmer, Ender of the Moon',
#  'Dreamkiss',
#  'Warped Diamond Crusader',
#  'Fury',
#  'Alpha',
#  'Righteous Might',
#  'Yearning Crusher',
#  'Soul Infused Crystal',
#  'Lifebender',
#  'Expiration, Warscythe Of Lost Worlds',
#  'Retribution Axe',
#  "Bloodlord's Fetish",
#  'Heartstriker, Legacy of the Light',
#  'Shadow Strike, Glory of Ending Hope',
#  'Brimstone',
#  "Dragon's Greatsword",
#  'Brutality Ivory Warmace',
#  'Lightning, Etcher of the King',
#  'Glinting Glass Edge',
#  'Serenity',
#  'Interrogator, Blood Blade of the Queen',
#  'Downfall, Scalpel Of The Emperor',
#  'Hailstorm Shadowsteel Scythe',
#  'Frenzied Scimitar',
#  'Celeste, Incarnation of the Corrupted',
#  'Piece Maker',
#  'Soul-Forged Steel Shortsword',
#  'Severance',
# ...

# %%
unique_count = len(pymoli1_rename.ItemName)
unique_count
# Out:
# 780

# %%
pricesums = sum(pymoli1_rename.Price) + sum(pymoli2_rename.Price)
pricesums
# Out:
# 4572.6599999999926

# %%
averagepp = pymoli1_rename.Price.mean() + pymoli2_rename.Price.mean()
averagepp
# Out:
# 5.862384615384606

# %%
total_purchase = len(pymoli1_rename.Price) + len(pymoli2_rename.Price)
total_purchase
# Out:
# 1560

# %%
total_revenue = pricesums
total_revenue
# Out:
# 4572.6599999999926

# %%
purchasing_analysis = pd.DataFrame({"Number of Unique Items": [unique_count],
                                   "Average Price": [averagepp],
                                   "Number of Purchases": [total_purchase],
                                   "Total Revenue": [total_revenue]})
purchasing_analysis
# Out:
#    Average Price  Number of Purchases  Number of Unique Items  Total Revenue
# 0       5.862385                 1560                     780        4572.66

# %%
malecount = len(Gender["Male"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-c310332da6e3> in <module>()
# ----> 1 malecount = len(Gender["Male"])
#
# NameError: name 'Gender' is not defined

# %%
pymoli1_rename['Gender'].value_counts()
# Out:
# Male                     633
# Female                   136
# Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
pymoli2_rename['Gender'].value_counts()
# Out:
# Male                     633
# Female                   136
# Other / Non-Disclosed     11
# Name: Gender, dtype: int64

# %%
percentmale = 633/780
percentmale
# Out:
# 0.8115384615384615

# %%
percentfemale = 136/870
percentfemale
# Out:
# 0.15632183908045977

# %%
percentother = 11/780
percentother
# Out:
# 0.014102564102564103

# %%
gender_analysis = pd.DataFrame({"Percent Male": [percentmale],
                                "Percent Female":[percentfemale],
                                "Percent Other":[percentother]})

gender_analysis
# Out:
#    Percent Female  Percent Male  Percent Other
# 0        0.156322      0.811538       0.014103

# %%
mpurchase = pymoli2_pd.groupby(['Gender']['Price']).count()
mpurchase
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-f5a1cf3ba292> in <module>()
# ----> 1 mpurchase = pymoli2_pd.groupby(['Gender']['Price']).count()
#       2 mpurchase
#
# TypeError: list indices must be integers or slices, not str

# %%
avpurprice = pymoli2_pd.groupby(['Gender','Price']).mean()
avpurprice
# Out:
#                               Age  Item ID
# Gender                Price
# Female                1.02   30.0    105.0
#                       1.74   20.0    170.0
#                       1.89   16.0      0.0
#                       2.26   21.0    108.0
#                       2.65   39.0      2.0
#                       2.95   23.0    118.0
#                       3.64   16.0     94.0
#                       3.85   11.0     41.0
#                       4.01   36.0    173.0
#                       4.12   20.0     90.0
#                       4.15   23.0    107.0
#                       4.39   23.0     68.0
#                       4.71   24.0    117.0
# Male                  1.08   29.0    126.0
#                       1.29   16.0     98.0
#                       1.31   20.5    121.5
#                       1.34   25.0    127.0
#                       1.36   24.0    174.0
#                       1.42    8.0      9.0
#                       1.62   32.0     23.0
# ...

# %%
totalpv = pymoli2_pd.groupby(['Gender','Price']).sum()
totalpv
# Out:
#                              Age  Item ID
# Gender                Price
# Female                1.02    30      105
#                       1.74    20      170
#                       1.89    16        0
#                       2.26    21      108
#                       2.65    39        2
#                       2.95    23      118
#                       3.64    16       94
#                       3.85    11       41
#                       4.01    36      173
#                       4.12    20       90
#                       4.15    23      107
#                       4.39    23       68
#                       4.71    24      117
# Male                  1.08    58      252
#                       1.29    32      196
#                       1.31    41      243
#                       1.34    25      127
#                       1.36    24      174
#                       1.42     8        9
#                       1.62    32       23
#                       1.77    21       82
# ...

# %%
normalized = pymoli2_pd.groupby('Gender')['Price'].count()
normalized
# Out:
# Gender
# Female                   13
# Male                     64
# Other / Non-Disclosed     1
# Name: Price, dtype: int64

# %%
gender_spending = pd.DataFrame({"Purchase Count": [mpurchase],
                                "Average Purchase Price":[avpurprice],
                                "Total Purchase Value":[totalpv],
                                "Normalized Totals": [normalized]})

gender_spending
# Out:
#                               Average Purchase Price  \
# 0                                Age  Item ID
# Gen...
#
#                                    Normalized Totals  \
# 0  Gender
# Female                   13
# Male       ...
#
#                                       Purchase Count  \
# 0                               Age  Item ID  Ite...
#
#                                 Total Purchase Value
# 0                               Age  Item ID
# Gend...

# %%
bins = [0, 5, 10, 15, 20, 25, 30, 40]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "40+"]

# %%
pcount = pymoli2_pd.groupby("Price")
pcount.max()
# Out:
#        Age                 Gender  Item ID  \
# Price
# 1.02    30                 Female      105
# 1.08    34                   Male      126
# 1.29    25                   Male       98
# 1.31    24                   Male      164
# 1.34    25                   Male      127
# 1.36    24                   Male      174
# 1.42     8                   Male        9
# 1.62    32                   Male       23
# 1.74    20                 Female      170
# 1.77    21                   Male       82
# 1.79    25                   Male      111
# 1.81    35                   Male       10
# 1.84    20                   Male      104
# 1.89    16                 Female        0
# 1.91    24                   Male        4
# 1.92    24                   Male       97
# 1.94    20                   Male      158
# 1.96    33                   Male       17
# 2.12    23  Other / Non-Disclosed      176
# 2.15    21                   Male      134
# ...

# %%
pcountmean = pcount.mean()
pcountmean
# Out:
#              Age     Item ID
# Price
# 1.02   30.000000  105.000000
# 1.08   29.000000  126.000000
# 1.29   16.000000   98.000000
# 1.31   20.500000  121.500000
# 1.34   25.000000  127.000000
# 1.36   24.000000  174.000000
# 1.42    8.000000    9.000000
# 1.62   32.000000   23.000000
# 1.74   20.000000  170.000000
# 1.77   21.000000   82.000000
# 1.79   21.500000  111.000000
# 1.81   35.000000   10.000000
# 1.84   20.000000  104.000000
# 1.89   16.000000    0.000000
# 1.91   24.000000    4.000000
# 1.92   24.000000   97.000000
# 1.94   20.000000  158.000000
# 1.96   33.000000   17.000000
# 2.12   17.500000  176.000000
# 2.15   20.500000   75.000000
# 2.22    8.000000    8.000000
# 2.26   20.500000  108.000000
# 2.42   22.500000   64.000000
# 2.55   17.000000  123.000000
# 2.63   24.500000   71.500000
# 2.65   39.000000    2.000000
# 2.70   27.500000   60.000000
# 2.71   16.000000  172.000000
# 2.77   19.000000  180.000000
# 2.82   20.000000   14.000000
# 2.88   33.000000  129.000000
# ...

# %%
pcounttotal = pcount.sum()
pcounttotal
# Out:
#        Age  Item ID
# Price
# 1.02    30      105
# 1.08    58      252
# 1.29    32      196
# 1.31    41      243
# 1.34    25      127
# 1.36    24      174
# 1.42     8        9
# 1.62    32       23
# 1.74    20      170
# 1.77    21       82
# 1.79    43      222
# 1.81    35       10
# 1.84    20      104
# 1.89    16        0
# 1.91    24        4
# 1.92    24       97
# 1.94    20      158
# 1.96    33       17
# 2.12    35      352
# 2.15    41      150
# 2.22     8        8
# 2.26    41      216
# 2.42    45      128
# 2.55    17      123
# 2.63    49      143
# 2.65    39        2
# 2.70    55      120
# 2.71    16      172
# 2.77    38      360
# 2.82    20       14
# 2.88    33      129
# 2.92    23       91
# 2.95    23      118
# 2.99    11      131
# 3.09    17       71
# 3.25    15      167
# 3.36    21       12
# 3.38    28       27
# 3.58    24        6
# 3.64    61      282
# 3.67    28        1
# 3.75    20       18
# 3.85    11       41
# 4.01    36      173
# ...

# %%
age_demo = pd.DataFrame({"Percent of Players": [bins],
                                "Total Count":[pcount]})

age_demo
# Out:
#                Percent of Players  \
# 0  [0, 5, 10, 15, 20, 25, 30, 40]
#
#                                          Total Count
# 0  <pandas.core.groupby.DataFrameGroupBy object a...

# %%
topspend = pymoli2_pd['SN'].groupby(pymoli2_pd['Price']).value_counts().idxmax
topspend
# Out:
# <bound method Series.idxmax of Price  SN
# 1.02   Undosian34       1
# 1.08   Chamalo71        1
#        Jiskimsda56      1
# 1.29   Lirtistanya48    1
#        Undadar97        1
# 1.31   Chaniman66       1
#        Yarmol79         1
# 1.34   Lirtastan49      1
# 1.36   Zhisrisu83       1
# 1.42   Aiduecal76       1
# 1.62   Hairith93        1
# 1.74   Sondassasya91    1
# 1.77   Aidaira26        1
# 1.79   Eolideu96        1
#        Iskadar31        1
# 1.81   Streural92       1
# 1.84   Ila44            1
# 1.89   Pharithdil38     1
# 1.91   Airi27           1
# 1.92   Chaniman66       1
# 1.94   Lassimla92       1
# 1.96   Chanjasksda31    1
# 2.12   Filon68          1
#        Inadeu25         1
# 2.15   Chrathybust28    1
#        Syalallodil59    1
# 2.22   Hainaria90       1
# 2.26   Airithrin43      1
#        Pheodaisun84     1
# 2.42   Saralp86         1
#                        ..
# 3.38   Undirra90        1
# 3.58   Lisosiast26      1
# 3.64   Seostylis96      1
# ...

# %%
pcount2 = pymoli2_pd['SN'].groupby(pymoli2_pd['Price']).value_counts()
pcount2
# Out:
# Price  SN
# 1.02   Undosian34       1
# 1.08   Chamalo71        1
#        Jiskimsda56      1
# 1.29   Lirtistanya48    1
#        Undadar97        1
# 1.31   Chaniman66       1
#        Yarmol79         1
# 1.34   Lirtastan49      1
# 1.36   Zhisrisu83       1
# 1.42   Aiduecal76       1
# 1.62   Hairith93        1
# 1.74   Sondassasya91    1
# 1.77   Aidaira26        1
# 1.79   Eolideu96        1
#        Iskadar31        1
# 1.81   Streural92       1
# 1.84   Ila44            1
# 1.89   Pharithdil38     1
# 1.91   Airi27           1
# 1.92   Chaniman66       1
# 1.94   Lassimla92       1
# 1.96   Chanjasksda31    1
# 2.12   Filon68          1
#        Inadeu25         1
# 2.15   Chrathybust28    1
#        Syalallodil59    1
# 2.22   Hainaria90       1
# 2.26   Airithrin43      1
#        Pheodaisun84     1
# 2.42   Saralp86         1
#                        ..
# 3.38   Undirra90        1
# 3.58   Lisosiast26      1
# 3.64   Seostylis96      1
#        Sondim43         1
# ...

# %%
mean2 = (pymoli2_pd['Price']).mean()
mean2
# Out:
# 2.9243589743589733

# %%
totalval = pymoli2_pd['SN'].groupby(pymoli2_pd['Price']).sum()
totalval
# Out:
# Price
# 1.02                             Undosian34
# 1.08                   Jiskimsda56Chamalo71
# 1.29                 Lirtistanya48Undadar97
# 1.31                     Yarmol79Chaniman66
# 1.34                            Lirtastan49
# 1.36                             Zhisrisu83
# 1.42                             Aiduecal76
# 1.62                              Hairith93
# 1.74                          Sondassasya91
# 1.77                              Aidaira26
# 1.79                     Eolideu96Iskadar31
# 1.81                             Streural92
# 1.84                                  Ila44
# 1.89                           Pharithdil38
# 1.91                                 Airi27
# 1.92                             Chaniman66
# 1.94                             Lassimla92
# 1.96                          Chanjasksda31
# 2.12                        Inadeu25Filon68
# 2.15             Chrathybust28Syalallodil59
# 2.22                             Hainaria90
# ...

# %%
top_spending = pd.DataFrame({"Purchase Count": [topspend],
                                "Average Purchase Price":[mean2],
                                "Total Purchase Value":[totalval]})

top_spending
# Out:
#    Average Purchase Price                                     Purchase Count  \
# 0                2.924359  <bound method Series.idxmax of Price  SN      ...
#
#                                 Total Purchase Value
# 0  Price
# 1.02                             Undosia...

# %%
popitem = pymoli2_pd['Item Name'].value_counts().idxmax()
popitem
# Out:
# 'Mourning Blade'

# %%
popid = pymoli2_pd['Item ID'].value_counts().idxmax()
popid
# Out:
# 94

# %%
poppurch = pymoli2_pd['Price'].value_counts().idxmax()
poppurch
# Out:
# 3.6400000000000001

# %%
totalpurch = pymoli2_pd['Item Name'].groupby(pymoli2_pd['Price']).sum()
totalpurch
# Out:
# Price
# 1.02                         Hailstorm Shadowsteel Scythe
# 1.08     Exiled Mithril LongswordExiled Mithril Longsword
# 1.29    Deadline, Voice Of SubtletyDeadline, Voice Of ...
# 1.31                  Alpha, Oath of ZealExiled Doomblade
# 1.34                         Heartseeker, Reaver of Souls
# 1.36                                      Primitive Blade
# 1.42                    Thorn, Conqueror of the Corrupted
# 1.62                                             Crucifer
# 1.74                                          Shadowsteel
# 1.77                                              Nirvana
# 1.79                             Misery's EndMisery's End
# 1.81                                          Sleepwalker
# 1.84                                   Gladiator's Glaive
# 1.89                                             Splinter
# 1.91                                   Bloodlord's Fetish
# 1.92                          Swan Song, Gouger Of Terror
# ...

# %%
popularitem = pd.DataFrame({"Item ID": [popid],
                                "Item Name":[popitem],
                                "Purchase Count":[poppurch],
                                "Purchase Values": [totalpurch]})

popularitem
# Out:
#    Item ID       Item Name  Purchase Count  \
# 0       94  Mourning Blade            3.64
#
#                                      Purchase Values
# 0  Price
# 1.02                         Hailstorm S...

# %%
profit_item = pymoli2_pd['Item Name'].groupby(pymoli2_pd['Price']).value_counts()
profit_item
# Out:
# Price  Item Name
# 1.02   Hailstorm Shadowsteel Scythe                 1
# 1.08   Exiled Mithril Longsword                     2
# 1.29   Deadline, Voice Of Subtlety                  2
# 1.31   Alpha, Oath of Zeal                          1
#        Exiled Doomblade                             1
# 1.34   Heartseeker, Reaver of Souls                 1
# 1.36   Primitive Blade                              1
# 1.42   Thorn, Conqueror of the Corrupted            1
# 1.62   Crucifer                                     1
# 1.74   Shadowsteel                                  1
# 1.77   Nirvana                                      1
# 1.79   Misery's End                                 2
# 1.81   Sleepwalker                                  1
# 1.84   Gladiator's Glaive                           1
# 1.89   Splinter                                     1
# 1.91   Bloodlord's Fetish                           1
# 1.92   Swan Song, Gouger Of Terror                  1
# ...

# %%
item_id = pymoli2_pd['Item ID'].groupby(pymoli2_pd['Price']).value_counts()
item_id
# Out:
# Price  Item ID
# 1.02   105        1
# 1.08   126        2
# 1.29   98         2
# 1.31   79         1
#        164        1
# 1.34   127        1
# 1.36   174        1
# 1.42   9          1
# 1.62   23         1
# 1.74   170        1
# 1.77   82         1
# 1.79   111        2
# 1.81   10         1
# 1.84   104        1
# 1.89   0          1
# 1.91   4          1
# 1.92   97         1
# 1.94   158        1
# 1.96   17         1
# 2.12   176        2
# 2.15   16         1
#        134        1
# 2.22   8          1
# 2.26   108        2
# 2.42   64         2
# 2.55   123        1
# 2.63   5          1
#        138        1
# 2.65   2          1
# 2.70   60         2
#                  ..
# 2.92   91         1
# 2.95   118        1
# 2.99   131        1
# 3.09   71         1
# 3.25   167        1
# 3.36   12         1
# 3.38   27         1
# 3.58   6          1
# 3.64   94         3
# 3.67   1          1
# 3.75   18         1
# 3.85   41         1
# 4.01   173        1
# ...

# %%
pcount3 = pymoli2_pd['Item Name'].groupby(pymoli2_pd['Price']).value_counts()
pcount3
# Out:
# Price  Item Name
# 1.02   Hailstorm Shadowsteel Scythe                 1
# 1.08   Exiled Mithril Longsword                     2
# 1.29   Deadline, Voice Of Subtlety                  2
# 1.31   Alpha, Oath of Zeal                          1
#        Exiled Doomblade                             1
# 1.34   Heartseeker, Reaver of Souls                 1
# 1.36   Primitive Blade                              1
# 1.42   Thorn, Conqueror of the Corrupted            1
# 1.62   Crucifer                                     1
# 1.74   Shadowsteel                                  1
# 1.77   Nirvana                                      1
# 1.79   Misery's End                                 2
# 1.81   Sleepwalker                                  1
# 1.84   Gladiator's Glaive                           1
# 1.89   Splinter                                     1
# 1.91   Bloodlord's Fetish                           1
# 1.92   Swan Song, Gouger Of Terror                  1
# ...

# %%
price3 = pymoli2_pd['Item Name'].groupby(pymoli2_pd['Price']).value_counts().idxmax()
price3
# Out:
# (3.6400000000000001, 'Mourning Blade')

# %%
totalpv3 = pymoli2_pd['Item Name'].groupby(pymoli2_pd['Price']).sum()
totalpv3
# Out:
# Price
# 1.02                         Hailstorm Shadowsteel Scythe
# 1.08     Exiled Mithril LongswordExiled Mithril Longsword
# 1.29    Deadline, Voice Of SubtletyDeadline, Voice Of ...
# 1.31                  Alpha, Oath of ZealExiled Doomblade
# 1.34                         Heartseeker, Reaver of Souls
# 1.36                                      Primitive Blade
# 1.42                    Thorn, Conqueror of the Corrupted
# 1.62                                             Crucifer
# 1.74                                          Shadowsteel
# 1.77                                              Nirvana
# 1.79                             Misery's EndMisery's End
# 1.81                                          Sleepwalker
# 1.84                                   Gladiator's Glaive
# 1.89                                             Splinter
# 1.91                                   Bloodlord's Fetish
# 1.92                          Swan Song, Gouger Of Terror
# ...

# %%
most_profit = pd.DataFrame({"Item Name": [profit_item],
                                "Item ID":[item_id],
                                "Purchase Count":[pcount3],
                                "Item Price":[price3],
                                "Total Purchase Value":[totalpv3]})

most_profit
# Out:
#                                              Item ID  \
# 0  Price  Item ID
# 1.02   105        1
# 1.08   126 ...
#
#                                            Item Name              Item Price  \
# 0  Price  Item Name                              ...  (3.64, Mourning Blade)
#
#                                       Purchase Count  \
# 0  Price  Item Name                              ...
#
#                                 Total Purchase Value
# 0  Price
# 1.02                         Hailstorm S...
